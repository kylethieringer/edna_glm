# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import random 
import scipy.stats
import pandas as pd
import bases
import preprocessing
import glm_utils
import seaborn as sns

# %%
exptList = glob.glob(r'/run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/*')

# %%
ftrList = [os.path.basename(i).split('.csv')[0] for i in glob.glob(rf'{exptList[0]}/*2.csv')]
ftrList.extend(['distance_male_head_to_female_abdomen', 'pulse', 'sine'])

# %%
exptList = glm_utils.get_exptList(exptList, ftrList)
# Out:
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_162605_18159206_rig1_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220729_133606_18159211_rig1_1/sine.npy
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absfFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absmRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absmLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/OEL2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absmFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/abs_diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absfLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absmfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absfmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/abs_diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absfRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/distance_male_head_to_female_abdomen.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/pulse.npy does not exist
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_162800_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_134035_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_153150_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_153924_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_134035_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_150628_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_135650_18159206_rig1_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_115559_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220802_110253_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_134110_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_162800_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_135934_18159211_rig1_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220729_114601_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_161523_18159206_rig1_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_115711_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_125001_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_125351_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220802_145907_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140607_18159203_rig3_1/sine.npy
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absfFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absmRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absmLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/OEL2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absmFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/abs_diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absfLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absmfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absfmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/abs_diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absfRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/distance_male_head_to_female_abdomen.csv Does not exist
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_145857_18159206_rig1_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_115711_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_124320_18159211_rig1_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_153257_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220803_112924_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_161713_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220729_114601_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_153150_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_144028_18159211_rig1_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_153924_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_125351_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_124432_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_153257_18159112_rig3_2/sine.npy
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absfFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absmRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absmLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/OEL2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absmFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/abs_diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absfLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absmfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absfmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/abs_diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absfRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/distance_male_head_to_female_abdomen.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/pulse.npy does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/sine.npy does not exist
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_140237_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220803_153208_16276625_rig2_1/sine.npy

# %%
exptList
# Out:
# []

# %%
x, y = glm_utils.design_multi(exptList, ftrList, 450)
# Out:
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_162605_18159206_rig1_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220729_133606_18159211_rig1_1/sine.npy
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absfFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absmRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absmLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/OEL2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absmFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/abs_diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absfLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absmfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absfmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/abs_diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/absfRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/mLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/fLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/distance_male_head_to_female_abdomen.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_16276625_rig2_1/pulse.npy does not exist
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_162800_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_134035_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_153150_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_153924_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_134035_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_150628_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_135650_18159206_rig1_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_115559_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220802_110253_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_134110_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_162800_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_135934_18159211_rig1_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220729_114601_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_161523_18159206_rig1_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_115711_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140406_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_125001_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_125351_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220802_145907_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_140607_18159203_rig3_1/sine.npy
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absfFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absmRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absmLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/OEL2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absmFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/abs_diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absfLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absmfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absfmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/abs_diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/absfRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/mLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/fLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/distance_male_head_to_female_abdomen.csv Does not exist
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_145857_18159206_rig1_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_115711_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_124320_18159211_rig1_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_153257_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220803_112924_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_161713_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220729_114601_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_153150_18159111_rig2_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_144028_18159211_rig1_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_154727_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220728_153924_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220809_125351_18159203_rig3_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_124432_16276625_rig2_1/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220806_153257_18159112_rig3_2/sine.npy
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fFA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absfFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absmRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absmLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/OEL2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absmFV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/abs_diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absfLV2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absmfAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absfmAng2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/abs_diff_distance_F_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/absfRS2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/mLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/diff_distance_M_ANT2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/fLA2.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/distance_male_head_to_female_abdomen.csv Does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/pulse.npy does not exist
# /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/track_array_args.txt/sine.npy does not exist
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220805_140237_18159112_rig3_2/sine.npy
# ERROR with loading /run/user/1000/gvfs/smb-share:server=tigress-cifs.princeton.edu,share=fileset-mmurthy/eDNA/behavior/manipulated_summer22_AK_controls/220803_153208_16276625_rig2_1/sine.npy
# shape of x: (0,)
# shape of y: (0,)

# %%
x
# Out:
# array([], dtype=float64)
